# %% [markdown]
# # Etapa 1 - Visao Geral do Projeto
#
# Este notebook resume o fluxo pedido no PDF para a base CelebA-Spoof.
#
# ## Objetivos
#
# 1. Gerar embeddings com deep learning.
# 2. Gerar embeddings com metodo tradicional.
# 3. Visualizar os embeddings.
# 4. Usar os embeddings em um metodo classico.

# %% [markdown]
# ## Estrutura recomendada
#
# - `src/projeto_redes_neurais/`: modulos reutilizaveis.
# - `notebooks/`: analises interativas.
# - `artifacts/embeddings/`: embeddings salvos.
# - `reports/figures/`: figuras das projecoes.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
PROJECT_ROOT

# %% [markdown]
# ## Ordem sugerida de execucao
#
# 1. Abra `01_celeba_spoof_preparacao.ipynb`.
# 2. Gere embeddings profundos em `02_embeddings_deep.ipynb`.
# 3. Gere embeddings tradicionais e avalie em `03_embeddings_tradicionais_e_avaliacao.ipynb`.
