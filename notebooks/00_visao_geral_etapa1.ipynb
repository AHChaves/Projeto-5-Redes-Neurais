# %% [markdown]
# # Etapa 1 - Visao Geral do Projeto
#
# Este repositorio foi reorganizado para trabalhar apenas com notebooks `.ipynb`.
#
# ## Objetivos do projeto
#
# 1. Preparar a base CelebA Align.
# 2. Gerar embeddings com deep learning.
# 3. Gerar embeddings com metodo tradicional.
# 4. Visualizar os embeddings.
# 5. Usar os embeddings em um metodo classico.

# %% [markdown]
# ## Estrutura do repositorio
#
# - `notebooks/`: fluxo completo do trabalho.
# - `data/raw/`: armazenamento da base bruta.
# - `artifacts/embeddings/`: embeddings salvos em `.parquet`.
# - `reports/figures/`: figuras geradas nas analises.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
PROJECT_ROOT
# Out:
# PosixPath('/home/arthur/Documentos/Github/Projeto-5-Redes-Neurais')

# %% [markdown]
# ## Ordem sugerida de execucao
#
# 1. `01_celeba_spoof_preparacao.ipynb`
# 2. `02_embeddings_deep.ipynb`
# 3. `03_embeddings_tradicionais_e_avaliacao.ipynb`
#
# Cada notebook e autossuficiente e nao depende de arquivos `.py` externos.
